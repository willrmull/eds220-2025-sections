# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h1>Archive exploration</h1>
#
# ***
#
# The data contains information about arthropod prey dataa from 1945-2022.
# This is a synthesis from multiple sources.
# It is not sensative.
# It comes with an associated metadata file.

# %%
# View Metadata
pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')
# Out:
#                         attribute  \
# 0                           class
# 1                           order
# 2                          family
# 3                           genus
# 4                         species
# 5                             lat
# 6                            long
# 7                       eventDate
# 8                             day
# 9                           month
# 10                           year
# 11                institutionCode
# 12  coordinateUncertaintyInMeters
# 13                  basisOfRecord
# 14                individualCount
# 15                     datasetKey
# 16                           bio1
# 17                          bio10
# 18                          bio11
# 19                          bio12
# 20                          bio13
# 21                          bio14
# 22                          bio15
# 23                          bio16
# 24                          bio17
# 25                          bio18
# ...

# %%
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A23d42528-1048-45d4-85d1-7e13b666e744')
print(type(prey))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
pd.set_option("display.max.columns", None)
# Removes the limit on the number of columns displayed
prey
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2            Insecta  Hymenoptera           Apidae         Bombus
# 3            Insecta  Hymenoptera           Apidae           Apis
# 4            Insecta    Hemiptera        Lygaeidae     Oncopeltus
# ...              ...          ...              ...            ...
# 111151       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111152       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111153       Insecta  Hymenoptera       Formicidae     Liometopum
# 111154       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111155       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                           species        lat        long  \
# 0             Sympetrum corruptum  37.173971 -121.856329
# ...

# %% [markdown]
# <h1>Preliminary Exploration</h1>
#
# ***

# %%
# prey.head()
# Prints first five rows of data
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species  ...        bio9      dist     dem90_hf  \
# 0    Sympetrum corruptum  ...  196.067307  8.935099   352.799927
# 1  Armadillidium vulgare  ...  159.852875  2.005335   112.895271
# 2    Bombus vosnesenskii  ...  134.750717  4.422367  2315.607666
# 3         Apis mellifera  ...  213.238907  4.316342   199.882156
# 4   Oncopeltus fasciatus  ...  205.749908  0.651661    72.789574
#
#            lc_class         ndvi
# 0         grassland  6343.969238
# 1         grassland  4995.110352
# 2         grassland  5118.055664
# 3  closed_shrubland  3649.374756
# 4             urban  3468.256104
# ...

# %%
# prey.tail()
# Prints last five rows of data

# %%
# prey.info()
# Prints the types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111156 entries, 0 to 111155
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   class                          111156 non-null  object
#  1   order                          111054 non-null  object
#  2   family                         111156 non-null  object
#  3   genus                          111156 non-null  object
#  4   species                        111156 non-null  object
#  5   lat                            111156 non-null  float64
#  6   long                           111156 non-null  float64
#  7   eventDate                      111156 non-null  object
#  8   day                            110998 non-null  float64
#  9   month                          111127 non-null  float64
#  10  year                           111156 non-null  int64
#  11  institutionCode                110414 non-null  object
# ...

# %%
# prey.nunique()
# List numberof unique observations in each column
# Out:
# class                                 4
# order                                18
# family                               63
# genus                                92
# species                              97
# lat                               91909
# long                              91965
# eventDate                        102140
# day                                  31
# month                                12
# year                                 77
# institutionCode                      77
# coordinateUncertaintyInMeters      4450
# basisOfRecord                         4
# individualCount                      42
# datasetKey                           88
# ID                               111156
# bio1                              11778
# bio10                             11981
# bio11                             11803
# bio12                             12117
# bio13                             12020
# bio14                              4586
# ...

# %%
print(prey.shape)
# The number of rows and columns of the dataframe
# Out:
# (111156, 40)

# %%
print(prey.columns)
# Prints the column names of the data frame
# Out:
# Index(['class', 'order', 'family', 'genus', 'species', 'lat', 'long',
#        'eventDate', 'day', 'month', 'year', 'institutionCode',
#        'coordinateUncertaintyInMeters', 'basisOfRecord', 'individualCount',
#        'datasetKey', 'ID', 'bio1', 'bio10', 'bio11', 'bio12', 'bio13', 'bio14',
#        'bio15', 'bio16', 'bio17', 'bio18', 'bio19', 'bio2', 'bio3', 'bio4',
#        'bio5', 'bio6', 'bio7', 'bio8', 'bio9', 'dist', 'dem90_hf', 'lc_class',
#        'ndvi'],
#       dtype='object')

# %%
print(prey.dtypes)
# Prints data type of each columns

# %%
# Rename two columns to follow camel case
prey = prey.rename(columns={'institutionCode': 'institution_code', 'datasetKey': 'dataset_key'})

# %%
prey[(prey['year'].between(1992,2000))]

# %%
# Select latitude between 37.0 and 39.0
prey[(prey['basisOfRecord'] == 'PRESERVED_SPECIMEN') &
     (prey['year'].between(1992,2000)) &
     (prey['lat'].between(37.0,39.0))]
# Out:
#           class        order          family       genus  \
# 1732    Insecta   Orthoptera       Acrididae  Melanoplus
# 1741    Insecta   Orthoptera       Acrididae  Melanoplus
# 1744    Insecta   Orthoptera       Acrididae  Melanoplus
# 1746    Insecta   Orthoptera       Acrididae  Melanoplus
# 3819    Insecta  Hymenoptera          Apidae        Apis
# ...         ...          ...             ...         ...
# 109841  Insecta      Odonata       Aeshnidae        Anax
# 109842  Insecta  Hymenoptera          Apidae      Bombus
# 109843  Insecta  Hymenoptera          Apidae      Bombus
# 109844  Insecta      Odonata  Coenagrionidae    Ischnura
# 109845  Insecta  Hymenoptera          Apidae      Bombus
#
#                        species        lat        long             eventDate  \
# 1732    Melanoplus sanguinipes  38.826049 -120.108584  1998-10-11T00:00:00Z
# 1741    Melanoplus sanguinipes  37.522500 -118.206944  2000-07-23T00:00:00Z
# ...
